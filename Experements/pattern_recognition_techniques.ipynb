# %%
import sys
import os
from pathlib import Path
# Get the current working directory (where the notebook/script is running)
current_dir = Path(os.getcwd())
# Navigate to the 'main' folder (adjust if needed)
main_dir = str(current_dir.parent)  # If notebook is inside 'main'
# OR if notebook is outside 'main':
# main_dir = str(current_dir / "main")  # Assumes 'main' is a subfolder
sys.path.append(main_dir)
# Data Manipulation and Analysis
import numpy as np
from numpy import nan as npNaN
import pandas as pd
import pandas_ta as ta
# Data Visualization
import matplotlib.pyplot as plt
import mplfinance as mpf

# Financial Data Fetching
import yfinance as yf

# Machine Learning and Clustering
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import mean_squared_error
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# import the split lib to split the data into train and test
from sklearn.model_selection import train_test_split
from pyclustering.cluster.silhouette import silhouette_ksearch_type, silhouette_ksearch
from pyclustering.cluster.kmeans import kmeans
from pyclustering.cluster.center_initializer import kmeans_plusplus_initializer

# Deep Learning
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Pattern Mining and Similarity Measures
from Pattern.perceptually_important import find_pips
from Pattern.pip_pattern_miner import Pattern_Miner
from scipy.spatial.distance import euclidean, cityblock, cosine
from scipy.stats import pearsonr
from dtaidistance import dtw

# %% [markdown]
# # Get stock Data and train

# %%
data = pd.read_csv('C:/Users/yoonus/Documents/GitHub/Stock_AI_Predictor/Data/Stocks/BTCUSD60.csv')
data['Date'] = data['Date'].astype('datetime64[s]')
data = data.set_index('Date')
# trim the data to only include the first 50 data points
data = data.head(500)

#data = data[data.index < '01-01-2020']
arr = data['Close'].to_numpy()

pip_miner = Pattern_Miner(n_pips=5, lookback=24, hold_period=6)
pip_miner.train(arr)
clusters_patterns = pip_miner._pip_clusters
clusters_patterns
# Out:
# [[117, 118, 119, 123, 172, 174, 222, 234, 241, 244],
#  [0, 1, 2, 33, 144, 189],
#  [83,
#   85,
#   86,
#   98,
#   100,
#   111,
#   156,
#   158,
#   159,
#   160,
#   186,
#   190,
#   192,
#   193,
#   210,
#   212,
#   231],
#  [43, 44, 48, 67, 68, 125, 180, 216, 235],
#  [7, 8, 9, 37, 96, 97],
#  [110, 209],
#  [18, 27, 93, 142, 196, 198, 218, 228],
#  [10, 11, 12, 13, 88, 99, 101, 162, 185],
#  [14, 16, 87, 89, 163, 164],
#  [62, 170, 220],
#  [25, 40, 41, 42, 45, 47, 53, 65, 69, 124, 236, 246],
#  [132, 134, 238, 239],
#  [211, 230],
#  [19, 74, 113, 114, 219],
#  [29, 32, 34, 35, 146, 203],
#  [73, 157, 191, 197],
#  [79, 80, 138, 173, 175, 176, 177, 178, 237],
#  [3, 30, 31, 95, 229],
#  [82, 183],
#  [4, 5, 6, 28, 36, 143],
#  [76, 77, 184],
#  [38, 55, 56, 81, 131, 214],
#  [109, 112],
#  [91, 92, 103, 104, 165, 167, 217],
#  [50, 154, 168],
#  [71, 72],
#  [106, 187, 202, 205],
#  [94, 145, 149, 199, 200],
#  [59, 61, 102, 129, 130, 240, 242],
#  [84, 213, 232, 233],
#  [57, 58, 60, 152, 155, 169],
#  [105, 107, 108, 148, 188, 206, 207, 208],
#  [20, 63, 75],
#  [17, 26, 49, 54, 70, 141, 151, 153, 195, 225, 227],
#  [22, 24, 52, 66, 78],
#  [39, 120, 121, 122, 126, 127, 128, 133, 179, 245, 247],
#  [15, 46, 90, 140, 166, 215, 226],
#  [21, 23, 221],
#  [150, 161, 194],
#  [64, 135, 136, 137, 171, 243],
#  [181, 182],
#  [139, 223, 224],
#  [51, 115, 116],
#  [147, 201, 204]]

# %% [markdown]
# # Current Sequence

# %%
current_data = data.loc['2018-01-01':'2018-01-4']
# get the candles from 0 to 5
current_data = current_data['Close'].iloc[30:35]

# inictialize the scaler
scaler = MinMaxScaler()

# Example current input sequence (reshape it to match the input shape)
current_sequence = current_data.to_numpy()
# scale the current sequence
current_sequence = scaler.fit_transform(current_sequence.reshape(-1, 1)).flatten()

# plot the current sequence
plt.plot(current_sequence)

# %% [markdown]
# # ANN

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def build_classification_model(input_shape, n_classes):
    model = Sequential([
        LSTM(64, activation='tanh', return_sequences=True, input_shape=input_shape),
        BatchNormalization(),
        Dropout(0.3),
        LSTM(32, activation='tanh', return_sequences=False),
        Dense(n_classes, activation='softmax', name='classification'), 
    ])
    model.compile(optimizer=Adam(0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

def train_model(clusters):
    # clusters = list of lists of sequences
    # Example: clusters[0] = [sequence1, sequence2, ...] all representing class 0
    x = []
    y = []
    for label, cluster_sequences in enumerate(clusters_patterns):
        for idx in cluster_sequences:
            # get the pattern from the clusters
            seq = pip_miner._unique_pip_patterns[idx]
            x.append(seq)
            y.append(label)

    x = np.array(x)[..., np.newaxis]
    y = np.array(y)

    print('x shape:', x.shape)
    print('y shape:', y.shape)
    
    # Split the data
    X_train, X_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42)
    
    # Get input shape and number of classes
    input_shape = (X_train.shape[1], X_train.shape[2])
    n_classes = len(clusters)  # Each cluster gets its own class
    
    # Build model using the helper function
    model = build_classification_model(input_shape, n_classes)

    # Train the model
    history = model.fit(X_train, y_train, 
                       validation_data=(X_val, y_val), 
                       epochs=200, 
                       batch_size=16,
                       verbose=1)

    # Plot training history
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title('Loss')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title('Accuracy')

    plt.tight_layout()
    plt.show()
    
    return model ,X_val, y_val

def predict_label(model, sequence):
    # Reshape and add channel dimension
    sequence = np.array(sequence).reshape(1, -1, 1)
    probs = model.predict(sequence)[0]
    label = np.argmax(probs)  # Since we're using numeric labels directly
    return label, probs

if __name__ == "__main__":
    
    # Train the model
    model ,x_val , y_val= train_model(clusters_patterns)

    y_pred = np.argmax(model.predict(x_val), axis=1)
    cm = confusion_matrix(y_val, y_pred)

    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap='Blues')
    plt.title("Confusion Matrix")
    plt.show()
# Out:
# x shape: (248, 5, 1)
# y shape: (248,)
# Epoch 1/200
# c:\Users\yoonus\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.0199 - loss: 3.7886 - val_accuracy: 0.0200 - val_loss: 3.7842
# Epoch 2/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0778 - loss: 3.7289 - val_accuracy: 0.0200 - val_loss: 3.7801
# Epoch 3/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0911 - loss: 3.6741 - val_accuracy: 0.0200 - val_loss: 3.7749
# Epoch 4/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1146 - loss: 3.5970 - val_accuracy: 0.0200 - val_loss: 3.7654
# Epoch 5/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1113 - loss: 3.5256 - val_accuracy: 0.0200 - val_loss: 3.7525
# Epoch 6/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1098 - loss: 3.4347 - val_accuracy: 0.0200 - val_loss: 3.7360
# Epoch 7/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1365 - loss: 3.2983 - val_accuracy: 0.0600 - val_loss: 3.7145
# Epoch 8/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1668 - loss: 3.2269 - val_accuracy: 0.0600 - val_loss: 3.6868
# Epoch 9/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1612 - loss: 3.0792 - val_accuracy: 0.0600 - val_loss: 3.6560
# Epoch 10/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2168 - loss: 2.9628 - val_accuracy: 0.0800 - val_loss: 3.6135
# Epoch 11/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2129 - loss: 2.8827 - val_accuracy: 0.0800 - val_loss: 3.5628
# Epoch 12/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2102 - loss: 2.8233 - val_accuracy: 0.0800 - val_loss: 3.5191
# Epoch 13/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2819 - loss: 2.7428 - val_accuracy: 0.1000 - val_loss: 3.4626
# Epoch 14/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2585 - loss: 2.6376 - val_accuracy: 0.0800 - val_loss: 3.4218
# Epoch 15/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2416 - loss: 2.6776 - val_accuracy: 0.1200 - val_loss: 3.3476
# Epoch 16/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3032 - loss: 2.5218 - val_accuracy: 0.1000 - val_loss: 3.3194
# Epoch 17/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3328 - loss: 2.4706 - val_accuracy: 0.1600 - val_loss: 3.2484
# Epoch 18/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2823 - loss: 2.4975 - val_accuracy: 0.1800 - val_loss: 3.2128
# Epoch 19/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2820 - loss: 2.4641 - val_accuracy: 0.2200 - val_loss: 3.0945
# Epoch 20/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4207 - loss: 2.2696 - val_accuracy: 0.1800 - val_loss: 3.0869
# Epoch 21/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3991 - loss: 2.2644 - val_accuracy: 0.2200 - val_loss: 2.9891
# Epoch 22/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3650 - loss: 2.1806 - val_accuracy: 0.2600 - val_loss: 2.9168
# Epoch 23/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3765 - loss: 2.2735 - val_accuracy: 0.2200 - val_loss: 2.9306
# Epoch 24/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3398 - loss: 2.1637 - val_accuracy: 0.2800 - val_loss: 2.8191
# Epoch 25/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4170 - loss: 2.0242 - val_accuracy: 0.2600 - val_loss: 2.7708
# Epoch 26/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3730 - loss: 2.1410 - val_accuracy: 0.2800 - val_loss: 2.7243
# Epoch 27/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4166 - loss: 2.0334 - val_accuracy: 0.2200 - val_loss: 2.8159
# Epoch 28/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4189 - loss: 2.0144 - val_accuracy: 0.2600 - val_loss: 2.6104
# Epoch 29/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3985 - loss: 1.9946 - val_accuracy: 0.2400 - val_loss: 2.5403
# Epoch 30/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4587 - loss: 1.9146 - val_accuracy: 0.3000 - val_loss: 2.5147
# Epoch 31/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4560 - loss: 1.9320 - val_accuracy: 0.3000 - val_loss: 2.4233
# Epoch 32/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4517 - loss: 1.8662 - val_accuracy: 0.3200 - val_loss: 2.3388
# Epoch 33/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4798 - loss: 1.8302 - val_accuracy: 0.2600 - val_loss: 2.4102
# Epoch 34/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5204 - loss: 1.8030 - val_accuracy: 0.3200 - val_loss: 2.2397
# Epoch 35/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5202 - loss: 1.6769 - val_accuracy: 0.4000 - val_loss: 2.1438
# Epoch 36/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5270 - loss: 1.6854 - val_accuracy: 0.3400 - val_loss: 2.2273
# Epoch 37/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5452 - loss: 1.6785 - val_accuracy: 0.3800 - val_loss: 2.0582
# Epoch 38/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5224 - loss: 1.7213 - val_accuracy: 0.4400 - val_loss: 2.0049
# Epoch 39/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5140 - loss: 1.6878 - val_accuracy: 0.4200 - val_loss: 1.9534
# Epoch 40/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5506 - loss: 1.6644 - val_accuracy: 0.4400 - val_loss: 1.9096
# Epoch 41/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6338 - loss: 1.6260 - val_accuracy: 0.4000 - val_loss: 1.9596
# Epoch 42/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5492 - loss: 1.6235 - val_accuracy: 0.4400 - val_loss: 1.8581
# Epoch 43/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6067 - loss: 1.6142 - val_accuracy: 0.4800 - val_loss: 1.7980
# Epoch 44/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6098 - loss: 1.5347 - val_accuracy: 0.4800 - val_loss: 1.8213
# Epoch 45/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6694 - loss: 1.4508 - val_accuracy: 0.5000 - val_loss: 1.7851
# Epoch 46/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6671 - loss: 1.4774 - val_accuracy: 0.4600 - val_loss: 1.7718
# Epoch 47/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6005 - loss: 1.5198 - val_accuracy: 0.5000 - val_loss: 1.7290
# Epoch 48/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5848 - loss: 1.4946 - val_accuracy: 0.4800 - val_loss: 1.7425
# Epoch 49/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6290 - loss: 1.4512 - val_accuracy: 0.4400 - val_loss: 1.7108
# Epoch 50/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6870 - loss: 1.3453 - val_accuracy: 0.5600 - val_loss: 1.6817
# Epoch 51/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6575 - loss: 1.4066 - val_accuracy: 0.5200 - val_loss: 1.5764
# Epoch 52/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7423 - loss: 1.3127 - val_accuracy: 0.5400 - val_loss: 1.5771
# Epoch 53/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7380 - loss: 1.2760 - val_accuracy: 0.5800 - val_loss: 1.5713
# Epoch 54/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7400 - loss: 1.3226 - val_accuracy: 0.5400 - val_loss: 1.5361
# Epoch 55/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6723 - loss: 1.3441 - val_accuracy: 0.5600 - val_loss: 1.5529
# Epoch 56/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7746 - loss: 1.2546 - val_accuracy: 0.5400 - val_loss: 1.5594
# Epoch 57/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7202 - loss: 1.2461 - val_accuracy: 0.5800 - val_loss: 1.4836
# Epoch 58/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7684 - loss: 1.1227 - val_accuracy: 0.5600 - val_loss: 1.5156
# Epoch 59/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7121 - loss: 1.2438 - val_accuracy: 0.5800 - val_loss: 1.4514
# Epoch 60/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7386 - loss: 1.1844 - val_accuracy: 0.5400 - val_loss: 1.4575
# Epoch 61/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7716 - loss: 1.1688 - val_accuracy: 0.6000 - val_loss: 1.4283
# Epoch 62/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7669 - loss: 1.1676 - val_accuracy: 0.6200 - val_loss: 1.4102
# Epoch 63/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7743 - loss: 1.1512 - val_accuracy: 0.5600 - val_loss: 1.4939
# Epoch 64/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7397 - loss: 1.1555 - val_accuracy: 0.6200 - val_loss: 1.4104
# Epoch 65/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7920 - loss: 1.0078 - val_accuracy: 0.6200 - val_loss: 1.3946
# Epoch 66/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8290 - loss: 1.0317 - val_accuracy: 0.6400 - val_loss: 1.3512
# Epoch 67/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7779 - loss: 1.0360 - val_accuracy: 0.6200 - val_loss: 1.3588
# Epoch 68/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7874 - loss: 1.0517 - val_accuracy: 0.5800 - val_loss: 1.3617
# Epoch 69/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7435 - loss: 1.0689 - val_accuracy: 0.6800 - val_loss: 1.3114
# Epoch 70/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7669 - loss: 0.9877 - val_accuracy: 0.6600 - val_loss: 1.3388
# Epoch 71/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7591 - loss: 1.0243 - val_accuracy: 0.6200 - val_loss: 1.3322
# Epoch 72/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8013 - loss: 0.9619 - val_accuracy: 0.6200 - val_loss: 1.2861
# Epoch 73/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7952 - loss: 0.9154 - val_accuracy: 0.6800 - val_loss: 1.2629
# Epoch 74/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8122 - loss: 0.9415 - val_accuracy: 0.6800 - val_loss: 1.2284
# Epoch 75/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8178 - loss: 0.8870 - val_accuracy: 0.6600 - val_loss: 1.2261
# Epoch 76/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8358 - loss: 0.8900 - val_accuracy: 0.6800 - val_loss: 1.1903
# Epoch 77/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8220 - loss: 0.9534 - val_accuracy: 0.6600 - val_loss: 1.1983
# Epoch 78/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8237 - loss: 0.8770 - val_accuracy: 0.7200 - val_loss: 1.1728
# Epoch 79/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8648 - loss: 0.8055 - val_accuracy: 0.6800 - val_loss: 1.1621
# Epoch 80/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8341 - loss: 0.8447 - val_accuracy: 0.6400 - val_loss: 1.1525
# Epoch 81/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7791 - loss: 0.8473 - val_accuracy: 0.6600 - val_loss: 1.1690
# Epoch 82/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8313 - loss: 0.8006 - val_accuracy: 0.7000 - val_loss: 1.1693
# Epoch 83/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8319 - loss: 0.8005 - val_accuracy: 0.6400 - val_loss: 1.1699
# Epoch 84/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8613 - loss: 0.8274 - val_accuracy: 0.6800 - val_loss: 1.1241
# Epoch 85/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8827 - loss: 0.7545 - val_accuracy: 0.6800 - val_loss: 1.0853
# Epoch 86/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8628 - loss: 0.7952 - val_accuracy: 0.6400 - val_loss: 1.1162
# Epoch 87/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8470 - loss: 0.8303 - val_accuracy: 0.7000 - val_loss: 1.0839
# Epoch 88/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8478 - loss: 0.8413 - val_accuracy: 0.7000 - val_loss: 1.0898
# Epoch 89/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8544 - loss: 0.7494 - val_accuracy: 0.6800 - val_loss: 1.0581
# Epoch 90/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8769 - loss: 0.7360 - val_accuracy: 0.7000 - val_loss: 1.0331
# Epoch 91/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8408 - loss: 0.7389 - val_accuracy: 0.7200 - val_loss: 1.0304
# Epoch 92/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8285 - loss: 0.7509 - val_accuracy: 0.7200 - val_loss: 1.0428
# Epoch 93/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8686 - loss: 0.7160 - val_accuracy: 0.7200 - val_loss: 1.0293
# Epoch 94/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8642 - loss: 0.6940 - val_accuracy: 0.7600 - val_loss: 0.9976
# Epoch 95/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8715 - loss: 0.7246 - val_accuracy: 0.7600 - val_loss: 1.0381
# Epoch 96/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8489 - loss: 0.7041 - val_accuracy: 0.7000 - val_loss: 1.0305
# Epoch 97/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8454 - loss: 0.7187 - val_accuracy: 0.6800 - val_loss: 1.0465
# Epoch 98/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8711 - loss: 0.6691 - val_accuracy: 0.7400 - val_loss: 0.9539
# Epoch 99/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8662 - loss: 0.6532 - val_accuracy: 0.8200 - val_loss: 0.9732
# Epoch 100/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8759 - loss: 0.6410 - val_accuracy: 0.7400 - val_loss: 0.9862
# Epoch 101/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8584 - loss: 0.6446 - val_accuracy: 0.7600 - val_loss: 0.9593
# Epoch 102/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8683 - loss: 0.6790 - val_accuracy: 0.7600 - val_loss: 0.9498
# Epoch 103/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8574 - loss: 0.6709 - val_accuracy: 0.7600 - val_loss: 0.9392
# Epoch 104/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9106 - loss: 0.5673 - val_accuracy: 0.7000 - val_loss: 0.9436
# Epoch 105/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8916 - loss: 0.6061 - val_accuracy: 0.7600 - val_loss: 0.9177
# Epoch 106/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9157 - loss: 0.5540 - val_accuracy: 0.7200 - val_loss: 0.9476
# Epoch 107/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8576 - loss: 0.5973 - val_accuracy: 0.7600 - val_loss: 0.9516
# Epoch 108/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9312 - loss: 0.5630 - val_accuracy: 0.7600 - val_loss: 0.8794
# Epoch 109/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9189 - loss: 0.5470 - val_accuracy: 0.7400 - val_loss: 0.8964
# Epoch 110/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8581 - loss: 0.6973 - val_accuracy: 0.8000 - val_loss: 0.8472
# Epoch 111/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8895 - loss: 0.5996 - val_accuracy: 0.7600 - val_loss: 0.8605
# Epoch 112/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9056 - loss: 0.5365 - val_accuracy: 0.7600 - val_loss: 0.8681
# Epoch 113/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9000 - loss: 0.5242 - val_accuracy: 0.7400 - val_loss: 0.8750
# Epoch 114/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9355 - loss: 0.4657 - val_accuracy: 0.7600 - val_loss: 0.8482
# Epoch 115/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9077 - loss: 0.5386 - val_accuracy: 0.8000 - val_loss: 0.8505
# Epoch 116/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9471 - loss: 0.5285 - val_accuracy: 0.7600 - val_loss: 0.8362
# Epoch 117/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9156 - loss: 0.5325 - val_accuracy: 0.7600 - val_loss: 0.8430
# Epoch 118/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9329 - loss: 0.4725 - val_accuracy: 0.7600 - val_loss: 0.8568
# Epoch 119/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8903 - loss: 0.5763 - val_accuracy: 0.7600 - val_loss: 0.8270
# Epoch 120/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9051 - loss: 0.5586 - val_accuracy: 0.7800 - val_loss: 0.7924
# Epoch 121/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9185 - loss: 0.4857 - val_accuracy: 0.7600 - val_loss: 0.8228
# Epoch 122/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9184 - loss: 0.4599 - val_accuracy: 0.7200 - val_loss: 0.8934
# Epoch 123/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9287 - loss: 0.4766 - val_accuracy: 0.8200 - val_loss: 0.8229
# Epoch 124/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9638 - loss: 0.4158 - val_accuracy: 0.8000 - val_loss: 0.7900
# Epoch 125/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9742 - loss: 0.4194 - val_accuracy: 0.7600 - val_loss: 0.7965
# Epoch 126/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9219 - loss: 0.4520 - val_accuracy: 0.7600 - val_loss: 0.8359
# Epoch 127/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9326 - loss: 0.4334 - val_accuracy: 0.7200 - val_loss: 0.7988
# Epoch 128/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9211 - loss: 0.4241 - val_accuracy: 0.7800 - val_loss: 0.7478
# Epoch 129/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9070 - loss: 0.4909 - val_accuracy: 0.7400 - val_loss: 0.8291
# Epoch 130/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8698 - loss: 0.4916 - val_accuracy: 0.7600 - val_loss: 0.7751
# Epoch 131/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8765 - loss: 0.4672 - val_accuracy: 0.7000 - val_loss: 0.8286
# Epoch 132/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9222 - loss: 0.4480 - val_accuracy: 0.8200 - val_loss: 0.7394
# Epoch 133/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9518 - loss: 0.3687 - val_accuracy: 0.7600 - val_loss: 0.7830
# Epoch 134/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9748 - loss: 0.4068 - val_accuracy: 0.8000 - val_loss: 0.7233
# Epoch 135/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9556 - loss: 0.3698 - val_accuracy: 0.7800 - val_loss: 0.7532
# Epoch 136/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9329 - loss: 0.3958 - val_accuracy: 0.7800 - val_loss: 0.7320
# Epoch 137/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9494 - loss: 0.3994 - val_accuracy: 0.8000 - val_loss: 0.7260
# Epoch 138/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9281 - loss: 0.4196 - val_accuracy: 0.7800 - val_loss: 0.7498
# Epoch 139/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9517 - loss: 0.3626 - val_accuracy: 0.7600 - val_loss: 0.8276
# Epoch 140/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9590 - loss: 0.3735 - val_accuracy: 0.8000 - val_loss: 0.7502
# Epoch 141/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9246 - loss: 0.3973 - val_accuracy: 0.7800 - val_loss: 0.7829
# Epoch 142/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9444 - loss: 0.3656 - val_accuracy: 0.8000 - val_loss: 0.7648
# Epoch 143/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9308 - loss: 0.4261 - val_accuracy: 0.8400 - val_loss: 0.7172
# Epoch 144/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9414 - loss: 0.3761 - val_accuracy: 0.7800 - val_loss: 0.7170
# Epoch 145/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9798 - loss: 0.3207 - val_accuracy: 0.7800 - val_loss: 0.7292
# Epoch 146/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9454 - loss: 0.3698 - val_accuracy: 0.7400 - val_loss: 0.7479
# Epoch 147/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9337 - loss: 0.3874 - val_accuracy: 0.8400 - val_loss: 0.7097
# Epoch 148/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9151 - loss: 0.3846 - val_accuracy: 0.8000 - val_loss: 0.7268
# Epoch 149/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9634 - loss: 0.3014 - val_accuracy: 0.7600 - val_loss: 0.7560
# Epoch 150/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8979 - loss: 0.4412 - val_accuracy: 0.8400 - val_loss: 0.6920
# Epoch 151/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9722 - loss: 0.3030 - val_accuracy: 0.8400 - val_loss: 0.6750
# Epoch 152/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9650 - loss: 0.3103 - val_accuracy: 0.8000 - val_loss: 0.7333
# Epoch 153/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9503 - loss: 0.3569 - val_accuracy: 0.8000 - val_loss: 0.7169
# Epoch 154/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9664 - loss: 0.3340 - val_accuracy: 0.8200 - val_loss: 0.6792
# Epoch 155/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9848 - loss: 0.2994 - val_accuracy: 0.8200 - val_loss: 0.6934
# Epoch 156/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9763 - loss: 0.2919 - val_accuracy: 0.8200 - val_loss: 0.6847
# Epoch 157/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9229 - loss: 0.3665 - val_accuracy: 0.8200 - val_loss: 0.6742
# Epoch 158/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9436 - loss: 0.3155 - val_accuracy: 0.8000 - val_loss: 0.7295
# Epoch 159/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9688 - loss: 0.3464 - val_accuracy: 0.8200 - val_loss: 0.6832
# Epoch 160/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9501 - loss: 0.3390 - val_accuracy: 0.7800 - val_loss: 0.7182
# Epoch 161/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9493 - loss: 0.3050 - val_accuracy: 0.8000 - val_loss: 0.6882
# Epoch 162/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9702 - loss: 0.3120 - val_accuracy: 0.8200 - val_loss: 0.6862
# Epoch 163/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9431 - loss: 0.3330 - val_accuracy: 0.7800 - val_loss: 0.7175
# Epoch 164/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9653 - loss: 0.2718 - val_accuracy: 0.8200 - val_loss: 0.6792
# Epoch 165/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9344 - loss: 0.3278 - val_accuracy: 0.8400 - val_loss: 0.6326
# Epoch 166/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9412 - loss: 0.3362 - val_accuracy: 0.8400 - val_loss: 0.7085
# Epoch 167/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9901 - loss: 0.2667 - val_accuracy: 0.8400 - val_loss: 0.6420
# Epoch 168/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9765 - loss: 0.2778 - val_accuracy: 0.8600 - val_loss: 0.6518
# Epoch 169/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9697 - loss: 0.2586 - val_accuracy: 0.8400 - val_loss: 0.6275
# Epoch 170/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9280 - loss: 0.3252 - val_accuracy: 0.8200 - val_loss: 0.6393
# Epoch 171/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9508 - loss: 0.2735 - val_accuracy: 0.8000 - val_loss: 0.6337
# Epoch 172/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9225 - loss: 0.2931 - val_accuracy: 0.8200 - val_loss: 0.6276
# Epoch 173/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.2413 - val_accuracy: 0.8400 - val_loss: 0.6271
# Epoch 174/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9659 - loss: 0.2785 - val_accuracy: 0.8400 - val_loss: 0.6065
# Epoch 175/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9877 - loss: 0.2475 - val_accuracy: 0.8200 - val_loss: 0.6071
# Epoch 176/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9831 - loss: 0.2421 - val_accuracy: 0.8400 - val_loss: 0.6333
# Epoch 177/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9599 - loss: 0.2693 - val_accuracy: 0.8200 - val_loss: 0.6212
# Epoch 178/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9762 - loss: 0.2607 - val_accuracy: 0.8200 - val_loss: 0.6006
# Epoch 179/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9458 - loss: 0.2858 - val_accuracy: 0.8200 - val_loss: 0.5976
# Epoch 180/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9639 - loss: 0.2678 - val_accuracy: 0.8400 - val_loss: 0.6009
# Epoch 181/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9603 - loss: 0.2428 - val_accuracy: 0.8200 - val_loss: 0.6036
# Epoch 182/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9691 - loss: 0.2417 - val_accuracy: 0.8000 - val_loss: 0.6319
# Epoch 183/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9775 - loss: 0.2579 - val_accuracy: 0.8200 - val_loss: 0.6032
# Epoch 184/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9538 - loss: 0.2469 - val_accuracy: 0.8600 - val_loss: 0.6118
# Epoch 185/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9754 - loss: 0.2381 - val_accuracy: 0.8200 - val_loss: 0.6013
# Epoch 186/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9638 - loss: 0.2449 - val_accuracy: 0.8400 - val_loss: 0.5706
# Epoch 187/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9839 - loss: 0.2220 - val_accuracy: 0.8200 - val_loss: 0.5948
# Epoch 188/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9663 - loss: 0.2457 - val_accuracy: 0.8200 - val_loss: 0.6216
# Epoch 189/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9756 - loss: 0.2199 - val_accuracy: 0.8200 - val_loss: 0.5945
# Epoch 190/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9597 - loss: 0.2637 - val_accuracy: 0.7800 - val_loss: 0.6477
# Epoch 191/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9834 - loss: 0.2289 - val_accuracy: 0.8200 - val_loss: 0.5904
# Epoch 192/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9415 - loss: 0.2720 - val_accuracy: 0.8200 - val_loss: 0.5865
# Epoch 193/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9600 - loss: 0.2333 - val_accuracy: 0.8000 - val_loss: 0.6781
# Epoch 194/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9542 - loss: 0.2733 - val_accuracy: 0.8400 - val_loss: 0.5905
# Epoch 195/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9685 - loss: 0.2263 - val_accuracy: 0.8200 - val_loss: 0.5841
# Epoch 196/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9521 - loss: 0.2546 - val_accuracy: 0.8000 - val_loss: 0.6137
# Epoch 197/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9770 - loss: 0.2123 - val_accuracy: 0.8200 - val_loss: 0.5790
# Epoch 198/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9719 - loss: 0.2243 - val_accuracy: 0.8200 - val_loss: 0.5857
# Epoch 199/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9571 - loss: 0.2577 - val_accuracy: 0.8200 - val_loss: 0.5435
# Epoch 200/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9716 - loss: 0.2201 - val_accuracy: 0.8400 - val_loss: 0.5596
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step

# %%
# Example prediction
test_sequence = current_sequence  # Example sequence to predict
lstm_idx, probs = predict_label(model, test_sequence)
print(f"Predicted cluster: {lstm_idx}, Probabilities: {probs}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Predicted cluster: 12, Probabilities: [1.44614149e-02 1.62155135e-03 5.46103343e-02 2.60675955e-03
#  8.48646536e-02 1.36117907e-02 1.59361545e-04 1.53187045e-03
#  5.51590114e-04 1.21626095e-03 2.55574821e-04 2.04532902e-04
#  5.82649469e-01 5.94088808e-03 9.43952799e-03 9.87756066e-03
#  8.75497889e-03 1.68377478e-02 3.85305728e-03 4.49640788e-02
#  3.85894300e-03 1.08018762e-03 4.46769446e-02 1.41358963e-04
#  2.94503057e-04 1.36962777e-03 2.55277124e-03 4.40389849e-03
#  1.09997396e-04 1.71105750e-02 1.79617971e-04 2.25450881e-02
#  4.34596324e-03 2.76095059e-04 8.05585459e-03 4.75645065e-03
#  4.81882569e-04 2.15145107e-03 5.75715303e-03 8.82637163e-04
#  1.41622708e-03 1.54982647e-03 2.39805109e-03 1.15920082e-02]

# %% [markdown]
# # rearrange current sequence

# %%
# create labels array based on the lengh of the clusters
labels = np.arange(0, len(pip_miner._cluster_centers))

# convert to numpy array
current_sequence = current_sequence.reshape(1, -1)
print(current_sequence.shape)
# Out:
# (1, 5)

# %% [markdown]
# # SVM

# %%
# Train an SVM classifier
svm = SVC(kernel='rbf')  # You can try 'linear', 'poly', or 'rbf' kernels
svm.fit(pip_miner._cluster_centers, labels)

def svm_predict(current_sequence):
    # Predict the pattern of the given sequence
    svm_index = svm.predict(current_sequence)

    return svm_index    
# Predict the pattern of the given sequence
svm_index = svm.predict(current_sequence)

print("Predicted pattern:", svm_index[0]+1)
# Out:
# Predicted pattern: 13

# %% [markdown]
# # RandomForest

# %%
# Train a Random Forest classifier
rf = RandomForestClassifier(n_estimators=100)
rf.fit(pip_miner._cluster_centers, labels)

def rf_predict(current_sequence):
    # Predict the pattern of the given sequence
    random_forest_index = rf.predict(current_sequence)

    return random_forest_index

# Predict the pattern of the given sequence
random_forest_index = rf.predict(current_sequence)

print("Predicted pattern:", random_forest_index[0]+1)
# Out:
# Predicted pattern: 5

# %% [markdown]
# # Euclidean Distance , Manhattan Distance , Cosine Similarity , Pearson Correlation , DTW Distance , MSE

# %%
# Reshape the query sequence to be 1-dimensional
query_sequence = current_sequence.reshape(-1)

# Function to compute similarity measures
def compute_similarity(query, sequence):
    # Euclidean Distance
    euclidean_dist = euclidean(query, sequence)
    
    # Manhattan Distance
    manhattan_dist = cityblock(query, sequence)
    
    # Cosine Similarity
    cosine_sim = 1 - cosine(query, sequence)  # scipy's cosine returns 1 - cosine similarity
    
    # Pearson Correlation
    pearson_corr, _ = pearsonr(query, sequence)
    
    # Dynamic Time Warping (DTW)
    dtw_dist = dtw.distance(query, sequence)
    
    # Mean Squared Error (MSE)
    mse = mean_squared_error(query, sequence)
    
    return {
        "Euclidean Distance": euclidean_dist,
        "Manhattan Distance": manhattan_dist,
        "Cosine Similarity": cosine_sim,
        "Pearson Correlation": pearson_corr,
        "DTW Distance": dtw_dist,
        "MSE": mse
    }

# Initialize variables to track the best match for each measure
best_matches = {
    "Euclidean Distance": {"index": -1, "value": float('inf')},
    "Manhattan Distance": {"index": -1, "value": float('inf')},
    "Cosine Similarity": {"index": -1, "value": -1},
    "Pearson Correlation": {"index": -1, "value": -1},
    "DTW Distance": {"index": -1, "value": float('inf')},
    "MSE": {"index": -1, "value": float('inf')}  # MSE is a distance measure (lower is better)
}

# Compare the query sequence with each sequence in the collection
for i, sequence in enumerate(pip_miner._cluster_centers):
    similarity_results = compute_similarity(query_sequence, sequence)
    
    # Update best matches for each measure
    for measure, value in similarity_results.items():
        if measure in ["Euclidean Distance", "Manhattan Distance", "DTW Distance", "MSE"]:
            if value < best_matches[measure]["value"]:
                best_matches[measure]["index"] = i
                best_matches[measure]["value"] = value
        else:  # Cosine Similarity and Pearson Correlation
            if value > best_matches[measure]["value"]:
                best_matches[measure]["index"] = i
                best_matches[measure]["value"] = value

# Print the best matches for each measure
print("Best Matches for Each Similarity Measure:")
for measure, match in best_matches.items():
    print(f"{measure}: Sequence {match['index']+1} with value {match['value']:.4f}")
    
# Get the index of the best match for each measure   
euclidean_index = best_matches["Euclidean Distance"]["index"]
manhattan_index = best_matches["Manhattan Distance"]["index"]
cosine_index = best_matches["Cosine Similarity"]["index"]
pearson_index = best_matches["Pearson Correlation"]["index"]
dtw_index = best_matches["DTW Distance"]["index"]
mse_index = best_matches["MSE"]["index"]
# Out:
# Best Matches for Each Similarity Measure:
# Euclidean Distance: Sequence 13 with value 0.3344
# Manhattan Distance: Sequence 13 with value 0.6300
# Cosine Similarity: Sequence 13 with value 0.9665
# Pearson Correlation: Sequence 13 with value 0.9400
# DTW Distance: Sequence 13 with value 0.3344
# MSE: Sequence 13 with value 0.0224

# %% [markdown]
# # Ploting

# %%
# Step 5: Plot the results
plt.figure(figsize=(14, 8))

# Plot the current pattern (only the 'Close' price for visualization)
plt.plot(current_sequence.flatten(), marker='o', label='Current Pattern (Close Price)', color='blue')

# Plot the most similar pattern using cosine similarity (only the 'Close' price for visualization)
plt.plot(pip_miner._cluster_centers[cosine_index], marker='o', label='Most Similar (Cosine)', color='green')

# Plot the most similar pattern using MSE (only the 'Close' price for visualization)
plt.plot(pip_miner._cluster_centers[mse_index], marker='o', label='Most Similar (MSE)', color='red')

# Plot the Random Forest predicted pattern
plt.plot(pip_miner._cluster_centers[random_forest_index[0]], marker='o', label='Random Forest Predicted Pattern', color='orange')

# Plot the SVM predicted pattern
plt.plot(pip_miner._cluster_centers[svm_index[0]], marker='o', label='SVM Predicted Pattern', color='brown')

# Plot the ANN predicted pattern
plt.plot(pip_miner._cluster_centers[0], marker='o', label='ANN Predicted Pattern', color='pink')

plt.title('Comparison of Current Pattern, Most Similar Patterns, and Model Predictions')
plt.xlabel('Time Steps')
plt.ylabel('Normalized Price Movement')
plt.legend()
plt.grid()
plt.show()
