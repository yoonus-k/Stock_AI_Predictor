# %%
# import libraries
import pandas as pd
import sqlite3 as db

# create a connection to the database
# conn = db.connect('Data/data.db')
conn = db.connect('Data/test.db')
# create a cursor object
cur = conn.cursor()

# get the dataframes from the database as a pandas dataframe
#df = pd.read_sql_query('SELECT * FROM employees', conn)
#print(df)

# %%
# create a table
cur.execute('CREATE TABLE IF NOT EXISTS employees (id INTEGER PRIMARY KEY, name TEXT, age INTEGER )')

# %%
# insert random 10 rows
cur.execute('INSERT INTO employees (name, age) VALUES (?, ?)', ('John', 30))
conn.commit()

# %%
# apply the changes to dataframes , remove the last row
df = df[:-1]

# %%
# update the database in employees table
df.to_sql('employees', conn, if_exists='replace', index=False)
# Out:
# 22

# %%
# close the connection to the database
conn.commit()
conn.close()
